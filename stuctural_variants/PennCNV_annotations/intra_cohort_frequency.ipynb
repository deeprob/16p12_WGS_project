# %%
# Get's intracohort structural variant count based on 
# 50% reciprocal overlap between structural variant

# %%
import pandas as pd
import numpy as np

# %%
svs = pd.read_csv('output/merged.PennCNV.tsv', sep='\t')

# %%
# loop over every chrom and svtype
chromosomes = list(svs.Chromosome.unique())
svtypes = ['dup', 'del']

for chrom in chromosomes:
    for svtype in svtypes:
        # get all structural variants in chromosome of the svtype
        sub_svs = svs[(svs.Chromosome == chrom) & (svs.Type == svtype)].copy()

        # create numpy structures for end, start, and svlength
        # (numpy is faster than pandas)
        chrom_ends = sub_svs['End'].to_numpy()
        chrom_starts = sub_svs['Start'].to_numpy()
        chrom_svlengths = sub_svs['Length'].to_numpy()

        # iterate over all structural variants in chrom
        # and compare against other structural variants in chrom
        for i, row in sub_svs.iterrows():
            start = row['Start']
            end = row['End']
            length = row['Length']

            min_end   = np.minimum(chrom_ends, end)
            max_start = np.maximum(chrom_starts, start)
            max_length = np.maximum(chrom_svlengths, length)

            overlap = (min_end - max_start) > .5 * max_length

            intra_cohort_count = overlap.sum()
            svs.at[i, 'intracohort_count'] = intra_cohort_count
            
svs['intracohort_count'] = svs['intracohort_count'].astype(int)

# %%
svs.to_csv('output/merged.PennCNV.intracohort.tsv', sep='\t', index=False)

# %%
svs
# Out:
#      Chromosome      Start        End  NumSNPs  Length Type    StartSNP  \
# 0          chr1     752721     854250        8  101530  dup   rs3131972
# 1          chr1     959842    1026707       16   66866  dup   rs2710888
# 2          chr1     959842    1040026       19   80185  dup   rs2710888
# 3          chr1     962210    1025301       13   63092  del   rs3128126
# 4          chr1     962210    1026707       15   64497  dup   rs3128126
# ...         ...        ...        ...      ...     ...  ...         ...
# 2603       chrX  149444023  149593953       23  149931  dup   rs9723612
# 2604       chrX  151170560  151239285        6   68726  dup  rs11798839
# 2605       chrX  152228236  152596189       20  367954  dup   rs1045059
# 2606       chrX  152480761  152626413       23  145653  dup   rs6627761
# 2607       chrX  153168154  153231748       15   63595  dup  rs12559136
#
#           EndSNP PatientID     %SD  %CenTel  Genes  \
# 0      rs7537756     SG172  0.9770   1.0000      5
# 1      rs4074137     SG467  0.0107   0.6006      3
# 2      rs6671356     SG469  0.0089   0.5008      3
# 3      rs9442400     SG045  0.0000   0.5990      3
# 4      rs4074137     SG404  0.0000   0.5859      3
# ...          ...       ...     ...      ...    ...
# 2603    rs683913     SG334  0.3775   0.0000      1
# 2604   rs1388517     SG399  0.0399   0.0000      0
# 2605  rs12841019     SG482  0.0049   0.0000      3
# 2606  rs12841273     SG177  0.0036   0.0000      2
# 2607  rs12011769     SG270  0.0000   0.0000      5
#
#                                             GeneList  intracohort_count
# 0     FAM87B,LINC00115,LINC01128,FAM41C,LOC100130417                  1
# 1                               AGRN,RNF223,C1orf159                  5
# 2                               AGRN,RNF223,C1orf159                 14
# 3                               AGRN,RNF223,C1orf159                  1
# 4                               AGRN,RNF223,C1orf159                  5
# ...                                              ...                ...
# 2603                                          MAMLD1                  1
# 2604                                             NaN                  1
# 2605                             PNMA3,PNMA6A,MAGEA1                  1
# 2606                                   MAGEA1,ZNF275                  1
# 2607                 AVPR2,ARHGAP4,NAA10,RENBP,HCFC1                  1
#
# [2608 rows x 14 columns]
